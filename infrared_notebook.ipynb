# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv("data/data.csv")
data.head()
# Out:
#   SubjectID  aveOralF  aveOralM  Gender    Age                  Ethnicity  \
# 0  161117-1     36.85     36.59    Male  41-50                      White
# 1  161117-2     37.00     37.19  Female  31-40  Black or African-American
# 2  161117-3     37.20     37.34  Female  21-30                      White
# 3  161117-4     36.85     37.09  Female  21-30  Black or African-American
# 4  161117-5     36.80     37.04    Male  18-20                      White
#
#    T_atm  Humidity  Distance  T_offset1  ...  T_FHCC1  T_FHRC1  T_FHLC1  \
# 0   24.0      28.0       0.8     0.7025  ...  33.5775  33.4775  33.3725
# 1   24.0      26.0       0.8     0.7800  ...  34.0325  34.0550  33.6775
# 2   24.0      26.0       0.8     0.8625  ...  34.9000  34.8275  34.6475
# 3   24.0      27.0       0.8     0.9300  ...  34.4400  34.4225  34.6550
# 4   24.0      27.0       0.8     0.8950  ...  35.0900  35.1600  34.3975
#
#    T_FHBC1  T_FHTC1  T_FH_Max1  T_FHC_Max1   T_Max1    T_OR1  T_OR_Max1
# ...

# %%
data.describe()
# Out:
#           aveOralF     aveOralM        T_atm     Humidity     Distance  \
# count  1020.000000  1020.000000  1020.000000  1020.000000  1018.000000
# mean     36.979216    37.028382    24.115392    28.723039     0.729784
# std       0.386403     0.509502     1.336338    13.071627     2.456486
# min      35.750000    35.540000    20.200000     9.900000     0.540000
# 25%      36.800000    36.777500    23.400000    17.600000     0.600000
# 50%      36.900000    36.940000    24.000000    26.300000     0.620000
# 75%      37.100000    37.140000    24.700000    36.200000     0.700000
# max      39.600000    40.340000    29.100000    61.200000    79.000000
#
#          T_offset1    Max1R13_1    Max1L13_1  aveAllR13_1  aveAllL13_1  ...  \
# count  1020.000000  1020.000000  1020.000000  1020.000000  1020.000000  ...
# mean      0.968648    35.596533    35.611474    34.888475    35.011345  ...
# std       0.362587     0.574888     0.549760     0.718613     0.633836  ...
# ...

# %%
inference_size = int(len(data) * 0.05)
inference_subset = data.sample(inference_size, random_state=42)
inference_subset.to_csv('data/inference_subset.csv', index=False)

# %%
inference = pd.read_csv("data/inference_subset.csv")
inference.head()
# Out:
#    SubjectID  aveOralF  aveOralM  Gender    Age                  Ethnicity  \
# 0  171107-04     36.90     37.09    Male  41-50  Black or African-American
# 1  171208-08     36.75     36.74    Male  31-40                      White
# 2  171108-02     36.75     36.79  Female  18-20                      White
# 3   161205-2     36.65     36.49    Male    >60                      Asian
# 4  180124-05     36.80     36.79    Male  26-30                      Asian
#
#    T_atm  Humidity  Distance  T_offset1  ...    T_FHCC1  T_FHRC1    T_FHLC1  \
# 0   24.1      30.2      0.70   0.807500  ...  34.440000  34.4750  34.380000
# 1   23.4      15.1      0.70   0.972500  ...  33.875000  33.5750  33.732500
# 2   25.4      28.2      0.65   1.150000  ...  34.567500  33.9600  34.957500
# 3   22.8      33.0      0.80   0.675000  ...  34.120000  33.8975  34.205000
# 4   23.8      20.6      0.60   0.763333  ...  34.713333  34.7300  34.756667
#
# ...
